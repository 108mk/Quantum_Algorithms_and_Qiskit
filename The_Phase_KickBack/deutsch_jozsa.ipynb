# %% [markdown]
# ## _*The Deutsch-Jozsa Algorithm*_
#
# The [Deutsch-Jozsa algorithm](http://rspa.royalsocietypublishing.org/content/439/1907/553) is one of the earliest examples demonstrating the power of quantum computers. The algorithm deals with guessing the type of a hidden Boolean function given as an oracle. The Boolean function is promised to be either balanced, i.e., whose values are $0$ on half of its inputs, or constant, i.e., whose values are the same on all inputs.
#
# Classically, in the best case, two queries to the oracle can determine if the hidden Boolean function is balanced; in the worst case, at least half of the inputs must be queried to determine if the hidden Boolean function is constant for all inputs. On the other hand, the Deutsch-Jozsa algorithm can determine the Boolean function with one quantum query.
#
# The latest version of this notebook is available on https://github.com/qiskit/qiskit-tutorial.
#
# ***
# ### Contributors
# Rudy Raymond
#
# ### Qiskit Package Versions

# %%
import qiskit
qiskit.__qiskit_version__
# Out:
# {'qiskit': '0.10.3',
#  'qiskit-terra': '0.8.1',
#  'qiskit-ignis': '0.1.1',
#  'qiskit-aer': '0.2.1',
#  'qiskit-ibmq-provider': '0.2.2',
#  'qiskit-aqua': '0.5.1'}

# %%
import qiskit
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.22.2', 'qiskit-aer': '0.11.1', 'qiskit-ignis': None, 'qiskit-ibmq-provider': '0.19.2', 'qiskit': '0.39.2', 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': None, 'qiskit-machine-learning': None}

# %% [markdown]
# ## Introduction <a id='introduction'></a>
#
# The algorithm in this notebook follows that in [Cleve et al. 1997](https://arxiv.org/pdf/quant-ph/9708016.pdf). We assume that the input to the oracle $f$ is a $n$-bit string. Namely, for each $x\ in \{0,1\}^n$, the value of $f(x)$ is promised to be either constant, i.e., the same for all $x$, or balanced, i.e., exactly half of the $n$-bit string whose $f(x) = 0$.

# %% [markdown]
# ## The Algorithm
#
# The algorithm is quite simple as follows.
# 1. Prepare two quantum registers initialized to zero. The first is an $n$-qubit reqister for querying the oracle, and the second is a one-qubit register for storing the answer of the oracle
# $$
# |0\ldots 0\rangle |0\rangle
# $$
# 2. Create the superposition of all input queries in the first register by applying the Hadamard gate to each qubit.
# $$
# H^{\otimes^n} |0\ldots 0\rangle |0\rangle = \frac{1}{\sqrt{2^n}}\sum_{i=0}^{2^n-1}|i\rangle |0\rangle
# $$
# 3. Flip the second register and apply the Hadamard gate. This is to store the answer of the oracle in the phase.
# $$
# \frac{1}{\sqrt{2^n}}\sum_{i=0}^{2^n-1}|i\rangle |0\rangle \rightarrow \frac{1}{\sqrt{2^{n+1}}}\sum_{i=0}^{2^n-1}|i\rangle ( |0\rangle - |1\rangle )
# $$
# 4. Query the oracle
# $$
# \frac{1}{\sqrt{2^{n+1}}}\sum_{i=0}^{2^n-1}|i\rangle ( |0\rangle - |1\rangle ) \rightarrow \frac{1}{\sqrt{2^{n+1}}}\sum_{i=0}^{2^n-1}(-1)^{f(i)}|i\rangle ( |0\rangle - |1\rangle )
# $$
# 5. Apply the Hadamard gate to the first register
#
# 6. Measure the first register. If it is non-zero, then conclude that the hidden Boolean function is balanced. Otherwise, conclude that it is constant.
#
# The correctness of the conclusion of the last step can be explained as follows.
#
# When the hidden Boolean function is constant, the quantum states before and after querying the oracle are the same. The inverse of the Hadamard gate is the Hadamard gate itself. Thus, by Step 5, we essentially reverse Step 2 to obtain the initial quantum state of all-zero at the first register.
#
# When the hidden Boolean function is balanced, the quantum state after querying the oracle is orthogonal to the quantum state before querying the oracle. Thus, by Step 5, when reverting the operation, we must end up with a quantum state that is orthogonal to the initial quantum state of all-zero at the first register. This means we should never obtain the all-zero state.

# %% [markdown]
# ## The Circuit <a id="circuit"></a>
#
# We now implement the Deutsch-Jozsa algorithm with Qiskit by first preparing the environment.

# %%
! pip install qiskit-ibm-runtime
# Out:
# Collecting qiskit-ibm-runtime
#   Downloading qiskit_ibm_runtime-0.8.0-py3-none-any.whl (190 kB)
#      |████████████████████████████████| 190 kB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.19 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-ibm-runtime) (2.23.0)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-ibm-runtime) (1.25.8)
# Collecting websocket-client<=1.3.3
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-ibm-runtime) (1.18.1)
# Collecting typing-extensions>=4.0.0
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting ibm-platform-services>=0.22.6
#   Downloading ibm-platform-services-0.30.2.tar.gz (237 kB)
#      |████████████████████████████████| 237 kB 3.2 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: qiskit-terra>=0.22 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-ibm-runtime) (0.22.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-ibm-runtime) (2.8.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-ibm-runtime) (1.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2.9)
# Collecting ibm-cloud-sdk-core<4.0.0,>=3.16.0
#   Downloading ibm_cloud_sdk_core-3.16.0-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.8 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.5 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (1.7.3)
# Requirement already satisfied: dill>=0.3 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (0.3.6)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (3.5.2)
# Requirement already satisfied: ply>=3.10 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: retworkx>=0.11.0 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (0.12.0)
# Requirement already satisfied: sympy>=1.3 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (1.5.1)
# Requirement already satisfied: tweedledum<2.0,>=1.1; python_version < "3.11" and (platform_machine != "arm64" or sys_platform != "darwin") in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (1.1.1)
# Requirement already satisfied: symengine>=0.9; platform_machine == "x86_64" or platform_machine == "aarch64" or platform_machine == "ppc64le" or platform_machine == "amd64" or platform_machine == "arm64" in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (0.9.2)
# Requirement already satisfied: shared-memory38; python_version < "3.8" in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (0.1.2)
# Requirement already satisfied: psutil>=5 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (5.7.0)
# Requirement already satisfied: importlib-metadata<5.0; python_version < "3.8" in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from qiskit-terra>=0.22->qiskit-ibm-runtime) (1.5.0)
# Requirement already satisfied: six>=1.5 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.14.0)
# Requirement already satisfied: cryptography>=1.3 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.8)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.5.0)
# Collecting PyJWT<3.0.0,>=2.4.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.22->qiskit-ibm-runtime) (5.11.0)
# Requirement already satisfied: rustworkx==0.12.0 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from retworkx>=0.11.0->qiskit-terra>=0.22->qiskit-ibm-runtime) (0.12.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from sympy>=1.3->qiskit-terra>=0.22->qiskit-ibm-runtime) (1.1.0)
# Requirement already satisfied: zipp>=0.5 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from importlib-metadata<5.0; python_version < "3.8"->qiskit-terra>=0.22->qiskit-ibm-runtime) (3.1.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.14.0)
# Requirement already satisfied: pycparser in /Users/manishkumar/anaconda3/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.20)
# Building wheels for collected packages: ibm-platform-services
#   Building wheel for ibm-platform-services (PEP 517) ... done
#   Created wheel for ibm-platform-services: filename=ibm_platform_services-0.30.2-py3-none-any.whl size=251981 sha256=24dbd305f999dc7d6bc2e20baeafbf287c88f5cc670e67873cd6ae79454894d9
#   Stored in directory: /Users/manishkumar/Library/Caches/pip/wheels/27/43/ec/463a4e88af155061e5e2d6e999f328f66b2b0447da0e6c7a93
# Successfully built ibm-platform-services
# ERROR: ibm-cloud-sdk-core 3.16.0 has requirement requests<3.0.0,>=2.26.0, but you'll have requests 2.23.0 which is incompatible.
# ERROR: ibm-cloud-sdk-core 3.16.0 has requirement urllib3<2.0.0,>=1.26.0, but you'll have urllib3 1.25.8 which is incompatible.
# ERROR: ibm-platform-services 0.30.2 has requirement requests<3.0.0,>=2.26.0, but you'll have requests 2.23.0 which is incompatible.
# ERROR: ibm-platform-services 0.30.2 has requirement urllib3<2.0.0,>=1.26.0, but you'll have urllib3 1.25.8 which is incompatible.
# Installing collected packages: websocket-client, typing-extensions, PyJWT, ibm-cloud-sdk-core, ibm-platform-services, qiskit-ibm-runtime
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.4.2
#     Uninstalling websocket-client-1.4.2:
#       Successfully uninstalled websocket-client-1.4.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.1
#     Uninstalling typing-extensions-3.7.4.1:
#       Successfully uninstalled typing-extensions-3.7.4.1
# Successfully installed PyJWT-2.6.0 ibm-cloud-sdk-core-3.16.0 ibm-platform-services-0.30.2 qiskit-ibm-runtime-0.8.0 typing-extensions-4.4.0 websocket-client-1.3.3

# %%
# useful additional packages 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# importing Qiskit
from qiskit import BasicAer, IBMQ
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
from qiskit.compiler import transpile
from qiskit.tools.monitor import job_monitor

# import basic plot tools
from qiskit.tools.visualization import plot_histogram

# %% [markdown]
# We first set the length of the $n$-bit string.

# %%
n = 10 # the length of the first register for querying the oracle

# %% [markdown]
# We then use Qiskit to program the algorithm.

# %%
# Choose a type of oracle at random. With probability half it is constant, 
# and with the same probability it is balanced
oracleType, oracleValue = np.random.randint(2), np.random.randint(2)

if oracleType == 0:
    print("The oracle returns a constant value ", oracleValue)
else:
    print("The oracle returns a balanced function")
    a = np.random.randint(1,2**n) # this is a hidden parameter for balanced oracle. 

# Creating registers
# n qubits for querying the oracle and one qubit for storing the answer
qr = QuantumRegister(n+1) #all qubits are initialized to zero
# for recording the measurement on the first register
cr = ClassicalRegister(n)

circuitName = "DeutschJozsa"
djCircuit = QuantumCircuit(qr, cr)

# Create the superposition of all input queries in the first register by applying the Hadamard gate to each qubit.
for i in range(n):
    djCircuit.h(qr[i])

# Flip the second register and apply the Hadamard gate.
djCircuit.x(qr[n])
djCircuit.h(qr[n])
    
# Apply barrier to mark the beginning of the oracle
djCircuit.barrier()

if oracleType == 0:#If the oracleType is "0", the oracle returns oracleValue for all input. 
    if oracleValue == 1:
        djCircuit.x(qr[n])
    else:
        djCircuit.iden(qr[n])
else: # Otherwise, it returns the inner product of the input with a (non-zero bitstring) 
    for i in range(n):
        if (a & (1 << i)):
            djCircuit.cx(qr[i], qr[n])
        
# Apply barrier to mark the end of the oracle
djCircuit.barrier()

# Apply Hadamard gates after querying the oracle
for i in range(n):
    djCircuit.h(qr[i])
    
# Measurement
djCircuit.barrier()
for i in range(n):
    djCircuit.measure(qr[i], cr[i])
# Out:
# The oracle returns a balanced function

# %% [markdown]
# ## Experiment with Simulators
#
# We can run the above circuit on the simulator.
#
# First, we draw the circuit.

# %%
#draw the circuit
djCircuit.draw(output='mpl',scale=1)

# %% [markdown]
# We then run the circuit on the simulator.

# %%
backend = BasicAer.get_backend('qasm_simulator')
shots = 1024
job = execute(djCircuit, backend=backend, shots=shots)
results = job.result() 
answer = results.get_counts()

plot_histogram(answer)

# %% [markdown]
# Repeating the above experiments, we can see that the result of the measurement is an all-zero bitstring if the oracle returns a constant value, or a non-zero bitstring otherwise.
#
# ## Experiment with Real Devices
#
# We can run the circuit on the real device as below. However, notice that because the real devices are noisy, we cannot obtain the type of oracles with certainty, unlike when running the experiments with simulators. The Deutsch-Jozsa algorithm only shows the superiority of quantum computers against exact classical algorithms; when allowing some error, classically we can determine the type of the hidden Boolean function with a constant number of queries. This is asymptotically the same as the case with quantum computers.

# %%
# Load our saved IBMQ accounts
from qiskit import IBMQ
IBMQ.save_account('752e72a0c99746a010b0c98fc18fc2fe9da45b9595448ec171c4bc206fe7ac79ff01843c26a27742d9ed6cf4d063fd66ec04127832d2a578f63afe4f32894d3a')

#IBMQ.providers('ibm-q')    # List all available providers
# Out:
# configrc.store_credentials:WARNING:2023-01-09 15:14:47,928: Credentials already present. Set overwrite=True to overwrite.

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
#backend = IBMQ.get_backend('ibmq_16_melbourne')
djCompiled = transpile(djCircuit, backend=backend, optimization_level=1)

# %%
djCompiled.draw(output='mpl',scale=1)

# %%
job = execute(djCompiled, backend=backend, shots=1024)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
results = job.result()
answer = results.get_counts()

threshold = int(0.01 * shots) # the threshold of plotting significant measurements
filteredAnswer = {k: v for k,v in answer.items() if v >= threshold} # filter the answer for better view of plots

removedCounts = np.sum([ v for k,v in answer.items() if v < threshold ]) # number of counts removed 
filteredAnswer['other_bitstrings'] = removedCounts  # the removed counts are assigned to a new index

plot_histogram(filteredAnswer)

# %%
results = job.result()
answer = results.get_counts()

threshold = int(0.01 * shots) # the threshold of plotting significant measurements
filteredAnswer = {k: v for k,v in answer.items() if v >= threshold} # filter the answer for better view of plots

removedCounts = np.sum([ v for k,v in answer.items() if v < threshold ]) # number of counts removed 
filteredAnswer['other_bitstrings'] = removedCounts  # the removed counts are assigned to a new index

plot_histogram(filteredAnswer)

# %%
print(filteredAnswer)
# Out:
# {'0011000001': 1024, 'other_bitstrings': 0.0}
